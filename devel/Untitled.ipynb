# %%
from edges_analysis.analysis.beams import antenna_beam_factor
from edges_analysis.analysis.sky_models import Haslam408
import numpy as np
from astropy.io import fits

# %%
h = Haslam408()

# %%
h.interpolate_freq(np.linspace(50,100,50))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-c4c99564891d> in <module>
# ----> 1 h.interpolate_freq(np.linspace(50,100,50))
#
# ~/Documents/Projects/radio/EOR/Edges/edges-analysis/src/edges_analysis/analysis/sky_models.py in interpolate_freq(self, freq_array, index_model, sigma_deg, index_center, index_pole, band_deg, index_inband, index_outband)
#     129
#     130         Tcmb = 2.725
# --> 131         sky_map = np.zeros((len(self.sky_map), len(freq_array)))
#     132         for i in range(len(freq_array)):
#     133             sky_map[:, i] = (self.sky_map - Tcmb) * (
#
# ~/miniconda3/envs/edges/lib/python3.7/site-packages/cached_property.py in __get__(self, obj, cls)
#      33             return self._wrap_in_coroutine(obj)
#      34
# ---> 35         value = obj.__dict__[self.func.__name__] = self.func(obj)
#      36         return value
#      37
#
# ...

# %%
with h.open() as fl:
    print(fl[1].data)
# Out:
# [(192.10422, 1.) (190.78244, 1.) (190.67949, 1.) ... (183.18246, 1.)
#  (181.32964, 1.) (182.89944, 1.)]

# %%
antenna_beam_factor('low')
# Out:
# /home/steven/Documents/Projects/radio/EOR/Edges/edges-analysis/src/edges_analysis/analysis/data/beams/low/default.txt
# ...
#  42%|████▏     | 11/26 [00:06<00:08,  1.84Frequencies/s]
# ...
# ...
# 100%|██████████| 72/72 [20:13<00:00, 16.48s/LSTs]cies/s]
# Writing out beam file to ~/edges-beams/low/beam_factors/feko_<edges_analysis.analysis.sky_models.Haslam408 object at 0x7f579329c048>_ref100.00_25809c5aab777f26c8613d371983ad0b.h5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/Documents/Projects/radio/EOR/Edges/edges-analysis/src/edges_analysis/analysis/io.py in _write(grp, struct, cache)
#     179
# --> 180                         grp[k] = v
#     181
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# ~/miniconda3/envs/edges/lib/python3.7/site-packages/h5py/_hl/attrs.py in __setitem__(self, name, value)
# ...
